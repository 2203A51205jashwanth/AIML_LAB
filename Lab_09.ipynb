# %% [markdown]
# <a href="https://colab.research.google.com/github/2203A51205jashwanth/AIML_LAB/blob/main/Lab_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
d1=pd.read_csv("loan_data.csv")
d1.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
d1.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
#summary of the dataset
d1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ##Display the Count of Credit Approvals done by the Company

# %%
print("following is a breakup of credit approval status.\n 1 means approved credits, 0 means not approved")
print(d1['credit.policy'].value_counts())
# Out:
# following is a breakup of credit approval status.
#  1 means approved credits, 0 means not approved
# 1    7710
# 0    1868
# Name: credit.policy, dtype: int64

# %% [markdown]
# ##Exploratory Data Analysis

# %%
#Histogram of FICO scores by credit approval status
d1[d1['credit.policy']==1] ['fico'].plot.hist(bins=30,alpha=0.5,color='blue',label='crecit.policy=1')
d1[d1['credit.policy']==0] ['fico'].plot.hist(bins=30,alpha=0.5,color='orange',label='crecit.policy=0')
plt.legend(fontsize=14)
plt.title("Histogram of FICO score by approved or disapproved credit policies",fontsize=15)
plt.xlabel("FICO score",fontsize=13)
# Out:
# Text(0.5, 0, 'FICO score')

# %% [markdown]
# ##presence or absence of statistical difference of various factors between credit approval status

# %%
sns.boxplot(x=d1['credit.policy'],y=d1['int.rate'])
plt.title("Intrest rate varies berween\n risky and non-risky borrowers",fontsize=14)
plt.xlabel("credit policy",fontsize=15)
plt.ylabel("Intrest rate",fontsize=15)
# Out:
# Text(0, 0.5, 'Intrest rate')

# %%
sns.boxplot(x=d1['credit.policy'],y=d1['log.annual.inc'])
plt.title("Intrest rate varies berween\n risky and non-risky borrowers",fontsize=14)
plt.xlabel("credit policy",fontsize=15)
plt.ylabel("Intrest rate",fontsize=15)
# Out:
# Text(0, 0.5, 'Intrest rate')

# %%
sns.boxplot(x=d1['credit.policy'],y=d1['dti'])
plt.title("Intrest rate varies berween\n risky and non-risky borrowers",fontsize=14)
plt.xlabel("credit policy",fontsize=15)
plt.ylabel("Intrest rate",fontsize=15)
# Out:
# Text(0, 0.5, 'Intrest rate')

# %%
sns.boxplot(x=d1['credit.policy'],y=d1['days.with.cr.line'])
plt.title("Intrest rate varies berween\n risky and non-risky borrowers",fontsize=14)
plt.xlabel("credit policy",fontsize=15)
plt.ylabel("Intrest rate",fontsize=15)
# Out:
# Text(0, 0.5, 'Intrest rate')

# %% [markdown]
# ##countplot of loans by purpose, with the color hue defined by not.fully.paid

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='purpose',hue='not.fully.paid',data=d1,palette='Set1')
plt.title("Bar chart of loan purpose colored \n by not fully paid status",fontsize=15)
plt.xlabel("purpose",fontsize=15)
# Out:
# Text(0.5, 0, 'purpose')

# %%
#Trend between FICO score and intrest rate
sns.jointplot(x='fico',y='int.rate',data=d1,color='purple',size=13)

# %%
sns.jointplot(x='purpose',y='int.rate',data=d1,color='blue',size=13)

# %%
sns.jointplot(x='credit.policy',y='int.rate',data=d1,color='pink',size=13)

# %% [markdown]
# ##implot to see if the trend differed between not.fully.paid and credit.policy

# %%
plt.figure(figsize=(14,7))
sns.lmplot(y='int.rate',x='fico',data=d1,hue='credit.policy',col='not.fully.paid',palette='Set1')

# %% [markdown]
# Setting up the Data<br>
# Categorical Features

# %%
#the purpose column as categorical. We transform the using dummy variables
d1_final=pd.get_dummies(d1,['purpose'],drop_first=True)

# %%
d1_final.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
x=d1_final.drop('not.fully.paid',axis=1)
y=d1_final['not.fully.paid']
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.30)

# %%
x_train.shape, y_test.shape
# Out:
# ((6704, 18), (2874,))

# %% [markdown]
# Training a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# create an instance of DecisionTreeClassifier()<br>
# called dtree and fit it to the tranning data.

# %%
dtree=DecisionTreeClassifier(criterion='gini',max_depth=None)

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Predictions and Evaluation of Decision Tree

# %%
predictions=dtree.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      2400
#            1       0.21      0.22      0.22       474
#
#     accuracy                           0.74      2874
#    macro avg       0.53      0.53      0.53      2874
# weighted avg       0.74      0.74      0.74      2874

# %%
cm=confusion_matrix(y_test,predictions)
print(cm)
print("Accuracy of prediction:",round((cm[0,0]+cm[1,1])/cm.sum(),3))
# Out:
# [[2014  386]
#  [ 369  105]]
# Accuracy of prediction: 0.737

# %% [markdown]
# Training the Random Forest Model

# %% [markdown]
# Now its time to train our model<br>
# create an insstance of the random forest classifier class and fit it to our training data from the previous step.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=600)
